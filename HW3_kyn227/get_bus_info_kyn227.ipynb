# %%
import pylab as pl
import traceback
import os
import json
try:
    import urllib2 as urllib
except ImportError:
    import urllib.request as urllib

# %pylab inline
pl.rc('font', size=15)

url = "http://bustime.mta.info/api/siri/vehicle-monitoring.json?key=06f927d1-679b-4e09-9062-cb337838097e&VehicleMonitoringDetailLevel=calls&LineRef=B52"
print (url)
response = urllib.urlopen(url)
data = response.read().decode("utf-8")
data = json.loads(data)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# http://bustime.mta.info/api/siri/vehicle-monitoring.json?key=06f927d1-679b-4e09-9062-cb337838097e&VehicleMonitoringDetailLevel=calls&LineRef=B52

# %%
(type(data))
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['Siri'])

# %%
url = "http://bustime.mta.info/api/siri/vehicle-monitoring.json?key=06f927d1-679b-4e09-9062-cb337838097e&VehicleMonitoringDetailLevel=calls&LineRef=B52"
print (url)
response = urllib.urlopen(url)
data = response.read().decode("utf-8")
data = json.loads(data)
# Out:
# http://bustime.mta.info/api/siri/vehicle-monitoring.json?key=06f927d1-679b-4e09-9062-cb337838097e&VehicleMonitoringDetailLevel=calls&LineRef=B52

# %%
data
# Out:
# {'Siri': {'ServiceDelivery': {'ResponseTimestamp': '2018-09-24T19:47:55.162-04:00',
#    'SituationExchangeDelivery': [],
#    'VehicleMonitoringDelivery': [{'ResponseTimestamp': '2018-09-24T19:47:55.162-04:00',
#      'ValidUntil': '2018-09-24T19:48:55.162-04:00',
#      'VehicleActivity': [{'MonitoredVehicleJourney': {'Bearing': 60.945396,
#         'BlockRef': 'MTA NYCT_FP_D8-Weekday-SDon_E_FP_13200_Q58-205',
#         'DestinationName': 'DNTWN BKLYN TILLARY ST via GATES',
#         'DestinationRef': 'MTA_901463',
#         'DirectionRef': '1',
#         'FramedVehicleJourneyRef': {'DataFrameRef': '2018-09-24',
#          'DatedVehicleJourneyRef': 'MTA NYCT_FP_D8-Weekday-SDon-112800_B52_126'},
#         'JourneyPatternRef': 'MTA_B520053',
#         'LineRef': 'MTA NYCT_B52',
#         'Monitored': True,
#         'MonitoredCall': {'Extensions': {'Distances': {'CallDistanceAlongRoute': 8065.26,
#            'DistanceFromCall': 30.46,
#            'PresentableDistance': 'at stop',
#            'StopsFromCall': 0}},
#          'StopPointName': 'CADMAN PLZ W/MONTAGUE ST',
#          'StopPointRef': 'MTA_306533',
#          'VisitNumber': 1},
#         'OnwardCalls': {'OnwardCall': [{'Extensions': {'Distances': {'CallDistanceAlongRoute': 8065.26,
#              'DistanceFromCall': 30.46,
#              'PresentableDistance': 'at stop',
#              'StopsFromCall': 0}},
#            'StopPointName': 'CADMAN PLZ W/MONTAGUE ST',
#            'StopPointRef': 'MTA_306533'},
#           {'ExpectedArrivalTime': '2018-09-24T19:48:04.561-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 8096.35,
#              'DistanceFromCall': 61.55,
#              'PresentableDistance': 'approaching',
#              'StopsFromCall': 1}},
#            'StopPointName': 'CADMAN PZ W/TILLARY ST',
#            'StopPointRef': 'MTA_901463'}]},
#         'OperatorRef': 'MTA NYCT',
#         'OriginRef': 'MTA_504965',
#         'ProgressRate': 'normalProgress',
#         'PublishedLineName': 'B52',
#         'SituationRef': [],
#         'VehicleLocation': {'Latitude': 40.693335, 'Longitude': -73.99059},
#         'VehicleRef': 'MTA NYCT_6526'},
#        'RecordedAtTime': '2018-09-24T19:47:43.000-04:00'},
#       {'MonitoredVehicleJourney': {'Bearing': 6.6020803,
#         'BlockRef': 'MTA NYCT_FP_D8-Weekday-SDon_E_FP_20040_Q55-307',
#         'DestinationName': 'RIDGEWOOD TERM via GATES',
#         'DestinationRef': 'MTA_801117',
#         'DirectionRef': '0',
#         'FramedVehicleJourneyRef': {'DataFrameRef': '2018-09-24',
#          'DatedVehicleJourneyRef': 'MTA NYCT_FP_D8-Weekday-SDon-116000_B52_124'},
#         'JourneyPatternRef': 'MTA_B520052',
#         'LineRef': 'MTA NYCT_B52',
#         'Monitored': True,
#         'MonitoredCall': {'ExpectedArrivalTime': '2018-09-24T19:47:58.337-04:00',
#          'ExpectedDepartureTime': '2018-09-24T19:47:58.337-04:00',
#          'Extensions': {'Distances': {'CallDistanceAlongRoute': 4027.09,
#            'DistanceFromCall': 52.03,
#            'PresentableDistance': 'approaching',
#            'StopsFromCall': 0}},
#          'StopPointName': 'GATES AV/BEDFORD AV',
#          'StopPointRef': 'MTA_307675',
#          'VisitNumber': 1},
#         'OnwardCalls': {'OnwardCall': [{'ExpectedArrivalTime': '2018-09-24T19:47:58.337-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4027.09,
#              'DistanceFromCall': 52.03,
#              'PresentableDistance': 'approaching',
#              'StopsFromCall': 0}},
#            'StopPointName': 'GATES AV/BEDFORD AV',
#            'StopPointRef': 'MTA_307675'},
#           {'ExpectedArrivalTime': '2018-09-24T19:48:57.513-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4291.16,
#              'DistanceFromCall': 316.11,
#              'PresentableDistance': '1 stop away',
#              'StopsFromCall': 1}},
#            'StopPointName': 'GATES AV/NOSTRAND AV',
#            'StopPointRef': 'MTA_307676'},
#           {'ExpectedArrivalTime': '2018-09-24T19:50:45.913-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4616.54,
#              'DistanceFromCall': 641.48,
#              'PresentableDistance': '2 stops away',
#              'StopsFromCall': 2}},
#            'StopPointName': 'GATES AV/MARCY AV',
#            'StopPointRef': 'MTA_307677'},
#           {'ExpectedArrivalTime': '2018-09-24T19:52:16.313-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4866.0,
#              'DistanceFromCall': 890.94,
#              'PresentableDistance': '0.6 miles away',
#              'StopsFromCall': 3}},
#            'StopPointName': 'GATES AV/TOMPKINS AV',
#            'StopPointRef': 'MTA_307678'},
#           {'ExpectedArrivalTime': '2018-09-24T19:53:58.713-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5103.34,
#              'DistanceFromCall': 1128.28,
#              'PresentableDistance': '0.7 miles away',
#              'StopsFromCall': 4}},
#            'StopPointName': 'GATES AV/THROOP AV',
#            'StopPointRef': 'MTA_307679'},
#           {'ExpectedArrivalTime': '2018-09-24T19:55:08.379-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5342.21,
#              'DistanceFromCall': 1367.16,
#              'PresentableDistance': '0.8 miles away',
#              'StopsFromCall': 5}},
#            'StopPointName': 'GATES AV/MARCUS GARVEY BL',
#            'StopPointRef': 'MTA_307680'},
#           {'ExpectedArrivalTime': '2018-09-24T19:56:50.979-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5591.01,
#              'DistanceFromCall': 1615.95,
#              'PresentableDistance': '1.0 miles away',
#              'StopsFromCall': 6}},
#            'StopPointName': 'GATES AV/LEWIS AV',
#            'StopPointRef': 'MTA_307681'},
#           {'ExpectedArrivalTime': '2018-09-24T19:57:51.384-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5842.65,
#              'DistanceFromCall': 1867.6,
#              'PresentableDistance': '1.2 miles away',
#              'StopsFromCall': 7}},
#            'StopPointName': 'GATES AV/STUYVESANT AV',
#            'StopPointRef': 'MTA_307682'},
#           {'ExpectedArrivalTime': '2018-09-24T19:59:14.779-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6092.05,
#              'DistanceFromCall': 2116.99,
#              'PresentableDistance': '1.3 miles away',
#              'StopsFromCall': 8}},
#            'StopPointName': 'GATES AV/MALCOLM X BL',
#            'StopPointRef': 'MTA_307683'},
#           {'ExpectedArrivalTime': '2018-09-24T20:00:20.779-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6337.9,
#              'DistanceFromCall': 2362.84,
#              'PresentableDistance': '1.5 miles away',
#              'StopsFromCall': 9}},
#            'StopPointName': 'GATES AV/PATCHEN AV',
#            'StopPointRef': 'MTA_307684'},
#           {'ExpectedArrivalTime': '2018-09-24T20:01:20.979-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6572.3,
#              'DistanceFromCall': 2597.25,
#              'PresentableDistance': '1.6 miles away',
#              'StopsFromCall': 10}},
#            'StopPointName': 'GATES AV/RALPH AV',
#            'StopPointRef': 'MTA_307901'},
#           {'ExpectedArrivalTime': '2018-09-24T20:02:12.979-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6734.12,
#              'DistanceFromCall': 2759.07,
#              'PresentableDistance': '1.7 miles away',
#              'StopsFromCall': 11}},
#            'StopPointName': 'GATES AV/BROADWAY',
#            'StopPointRef': 'MTA_307686'},
#           {'ExpectedArrivalTime': '2018-09-24T20:04:27.778-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6977.66,
#              'DistanceFromCall': 3002.6,
#              'PresentableDistance': '1.9 miles away',
#              'StopsFromCall': 12}},
#            'StopPointName': 'GATES AV/BUSHWICK AV',
#            'StopPointRef': 'MTA_307687'},
#           {'ExpectedArrivalTime': '2018-09-24T20:05:33.737-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7146.91,
#              'DistanceFromCall': 3171.85,
#              'PresentableDistance': '2.0 miles away',
#              'StopsFromCall': 13}},
#            'StopPointName': 'GATES AV/EVERGREEN AV',
#            'StopPointRef': 'MTA_307688'},
#           {'ExpectedArrivalTime': '2018-09-24T20:06:40.833-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7388.47,
#              'DistanceFromCall': 3413.42,
#              'PresentableDistance': '2.1 miles away',
#              'StopsFromCall': 14}},
#            'StopPointName': 'GATES AV/CENTRAL AV',
#            'StopPointRef': 'MTA_307689'},
#           {'ExpectedArrivalTime': '2018-09-24T20:07:48.433-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7591.7,
#              'DistanceFromCall': 3616.65,
#              'PresentableDistance': '2.2 miles away',
#              'StopsFromCall': 15}},
#            'StopPointName': 'GATES AV/WILSON AV',
#            'StopPointRef': 'MTA_307690'},
#           {'ExpectedArrivalTime': '2018-09-24T20:08:49.872-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7797.59,
#              'DistanceFromCall': 3822.53,
#              'PresentableDistance': '2.4 miles away',
#              'StopsFromCall': 16}},
#            'StopPointName': 'GATES AV/KNICKERBOCKER AV',
#            'StopPointRef': 'MTA_307691'},
#           {'ExpectedArrivalTime': '2018-09-24T20:10:13.916-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 8098.58,
#              'DistanceFromCall': 4123.52,
#              'PresentableDistance': '2.6 miles away',
#              'StopsFromCall': 17}},
#            'StopPointName': 'PALMETTO ST/IRVING AV',
#            'StopPointRef': 'MTA_304415'},
#           {'ExpectedArrivalTime': '2018-09-24T20:10:46.750-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 8248.54,
#              'DistanceFromCall': 4273.49,
#              'PresentableDistance': '2.7 miles away',
#              'StopsFromCall': 18}},
#            'StopPointName': 'PALMETTO ST/WYCKOFF AV',
#            'StopPointRef': 'MTA_801117'}]},
#         'OperatorRef': 'MTA NYCT',
#         'OriginRef': 'MTA_307175',
#         'ProgressRate': 'normalProgress',
#         'PublishedLineName': 'B52',
#         'SituationRef': [],
#         'VehicleLocation': {'Latitude': 40.685751, 'Longitude': -73.954574},
#         'VehicleRef': 'MTA NYCT_4445'},
#        'RecordedAtTime': '2018-09-24T19:47:32.000-04:00'},
#       {'MonitoredVehicleJourney': {'Bearing': 186.44011,
#         'BlockRef': 'MTA NYCT_FP_D8-Weekday-SDon_E_FP_23520_B52-111',
#         'DestinationName': 'DNTWN BKLYN TILLARY ST via GATES',
#         'DestinationRef': 'MTA_901463',
#         'DirectionRef': '1',
#         'FramedVehicleJourneyRef': {'DataFrameRef': '2018-09-24',
#          'DatedVehicleJourneyRef': 'MTA NYCT_FP_D8-Weekday-SDon-116000_B52_128'},
#         'JourneyPatternRef': 'MTA_B520053',
#         'LineRef': 'MTA NYCT_B52',
#         'Monitored': True,
#         'MonitoredCall': {'ExpectedArrivalTime': '2018-09-24T19:47:56.162-04:00',
#          'ExpectedDepartureTime': '2018-09-24T19:47:56.162-04:00',
#          'Extensions': {'Distances': {'CallDistanceAlongRoute': 3903.29,
#            'DistanceFromCall': 52.22,
#            'PresentableDistance': 'approaching',
#            'StopsFromCall': 0}},
#          'StopPointName': 'GATES AV/MARCY AV',
#          'StopPointRef': 'MTA_304211',
#          'VisitNumber': 1},
#         'OnwardCalls': {'OnwardCall': [{'ExpectedArrivalTime': '2018-09-24T19:47:55.162-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 3903.29,
#              'DistanceFromCall': 52.22,
#              'PresentableDistance': 'approaching',
#              'StopsFromCall': 0}},
#            'StopPointName': 'GATES AV/MARCY AV',
#            'StopPointRef': 'MTA_304211'},
#           {'ExpectedArrivalTime': '2018-09-24T19:49:19.796-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4183.96,
#              'DistanceFromCall': 332.89,
#              'PresentableDistance': '1 stop away',
#              'StopsFromCall': 1}},
#            'StopPointName': 'GATES AV/NOSTRAND AV',
#            'StopPointRef': 'MTA_304212'},
#           {'ExpectedArrivalTime': '2018-09-24T19:51:05.173-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4497.03,
#              'DistanceFromCall': 645.97,
#              'PresentableDistance': '2 stops away',
#              'StopsFromCall': 2}},
#            'StopPointName': 'GATES AV/BEDFORD AV',
#            'StopPointRef': 'MTA_304213'},
#           {'ExpectedArrivalTime': '2018-09-24T19:52:10.915-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4676.87,
#              'DistanceFromCall': 825.8,
#              'PresentableDistance': '0.5 miles away',
#              'StopsFromCall': 3}},
#            'StopPointName': 'GATES AV/FRANKLIN AV',
#            'StopPointRef': 'MTA_304214'},
#           {'ExpectedArrivalTime': '2018-09-24T19:53:01.485-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4864.43,
#              'DistanceFromCall': 1013.37,
#              'PresentableDistance': '0.6 miles away',
#              'StopsFromCall': 4}},
#            'StopPointName': 'GATES AV/CLASSON AV',
#            'StopPointRef': 'MTA_307948'},
#           {'ExpectedArrivalTime': '2018-09-24T19:54:37.485-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5156.07,
#              'DistanceFromCall': 1305.0,
#              'PresentableDistance': '0.8 miles away',
#              'StopsFromCall': 5}},
#            'StopPointName': 'GREENE AV/CLASSON AV',
#            'StopPointRef': 'MTA_307572'},
#           {'ExpectedArrivalTime': '2018-09-24T19:55:36.756-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5397.42,
#              'DistanceFromCall': 1546.35,
#              'PresentableDistance': '1.0 miles away',
#              'StopsFromCall': 6}},
#            'StopPointName': 'GREENE AV/GRAND AV',
#            'StopPointRef': 'MTA_307573'},
#           {'ExpectedArrivalTime': '2018-09-24T19:56:48.372-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5655.77,
#              'DistanceFromCall': 1804.7,
#              'PresentableDistance': '1.1 miles away',
#              'StopsFromCall': 7}},
#            'StopPointName': 'GREENE AV/WASHINGTON AV',
#            'StopPointRef': 'MTA_307596'},
#           {'ExpectedArrivalTime': '2018-09-24T19:58:06.782-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5907.49,
#              'DistanceFromCall': 2056.42,
#              'PresentableDistance': '1.3 miles away',
#              'StopsFromCall': 8}},
#            'StopPointName': 'GREENE AV/VANDERBILT AV',
#            'StopPointRef': 'MTA_307575'},
#           {'ExpectedArrivalTime': '2018-09-24T19:58:59.430-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6074.28,
#              'DistanceFromCall': 2223.22,
#              'PresentableDistance': '1.4 miles away',
#              'StopsFromCall': 9}},
#            'StopPointName': 'GREENE AV/ADELPHI ST',
#            'StopPointRef': 'MTA_307576'},
#           {'ExpectedArrivalTime': '2018-09-24T19:59:51.574-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6238.78,
#              'DistanceFromCall': 2387.72,
#              'PresentableDistance': '1.5 miles away',
#              'StopsFromCall': 10}},
#            'StopPointName': 'GREENE AV/CUMBERLAND ST',
#            'StopPointRef': 'MTA_307577'},
#           {'ExpectedArrivalTime': '2018-09-24T20:01:34.380-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6487.03,
#              'DistanceFromCall': 2635.96,
#              'PresentableDistance': '1.6 miles away',
#              'StopsFromCall': 11}},
#            'StopPointName': 'FULTON ST/S ELLIOTT PL',
#            'StopPointRef': 'MTA_302427'},
#           {'ExpectedArrivalTime': '2018-09-24T20:02:38.376-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6642.98,
#              'DistanceFromCall': 2791.91,
#              'PresentableDistance': '1.7 miles away',
#              'StopsFromCall': 12}},
#            'StopPointName': 'FULTON ST/FT GREENE PL',
#            'StopPointRef': 'MTA_302428'},
#           {'ExpectedArrivalTime': '2018-09-24T20:04:32.576-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6942.37,
#              'DistanceFromCall': 3091.31,
#              'PresentableDistance': '1.9 miles away',
#              'StopsFromCall': 13}},
#            'StopPointName': 'FULTON ST/HUDSON AV',
#            'StopPointRef': 'MTA_302430'},
#           {'ExpectedArrivalTime': '2018-09-24T20:06:23.845-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7193.37,
#              'DistanceFromCall': 3342.3,
#              'PresentableDistance': '2.1 miles away',
#              'StopsFromCall': 14}},
#            'StopPointName': 'FULTON ST/BOND ST',
#            'StopPointRef': 'MTA_302431'},
#           {'ExpectedArrivalTime': '2018-09-24T20:07:32.860-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7397.6,
#              'DistanceFromCall': 3546.53,
#              'PresentableDistance': '2.2 miles away',
#              'StopsFromCall': 15}},
#            'StopPointName': 'FULTON ST/DUFFIELD ST',
#            'StopPointRef': 'MTA_307492'},
#           {'ExpectedArrivalTime': '2018-09-24T20:08:42.260-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7605.4,
#              'DistanceFromCall': 3754.34,
#              'PresentableDistance': '2.3 miles away',
#              'StopsFromCall': 16}},
#            'StopPointName': 'FULTON ST/JAY ST',
#            'StopPointRef': 'MTA_302433'},
#           {'ExpectedArrivalTime': '2018-09-24T20:10:52.860-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7931.22,
#              'DistanceFromCall': 4080.15,
#              'PresentableDistance': '2.5 miles away',
#              'StopsFromCall': 17}},
#            'StopPointName': 'JORALEMON ST/COURT ST',
#            'StopPointRef': 'MTA_302434'},
#           {'Extensions': {'Distances': {'CallDistanceAlongRoute': 8065.26,
#              'DistanceFromCall': 4214.19,
#              'PresentableDistance': '2.6 miles away',
#              'StopsFromCall': 18}},
#            'StopPointName': 'CADMAN PLZ W/MONTAGUE ST',
#            'StopPointRef': 'MTA_306533'},
#           {'ExpectedArrivalTime': '2018-09-24T20:11:50.704-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 8096.35,
#              'DistanceFromCall': 4245.28,
#              'PresentableDistance': '2.6 miles away',
#              'StopsFromCall': 19}},
#            'StopPointName': 'CADMAN PZ W/TILLARY ST',
#            'StopPointRef': 'MTA_901463'}]},
#         'OperatorRef': 'MTA NYCT',
#         'OriginRef': 'MTA_504965',
#         'ProgressRate': 'normalProgress',
#         'PublishedLineName': 'B52',
#         'SituationRef': [],
#         'VehicleLocation': {'Latitude': 40.686575, 'Longitude': -73.947251},
#         'VehicleRef': 'MTA NYCT_6583'},
#        'RecordedAtTime': '2018-09-24T19:47:27.000-04:00'},
#       {'MonitoredVehicleJourney': {'Bearing': 268.26428,
#         'BlockRef': 'MTA NYCT_FP_D8-Weekday-SDon_E_FP_58200_B52-134',
#         'DestinationName': 'RIDGEWOOD TERM via GATES',
#         'DestinationRef': 'MTA_801117',
#         'DirectionRef': '0',
#         'FramedVehicleJourneyRef': {'DataFrameRef': '2018-09-24',
#          'DatedVehicleJourneyRef': 'MTA NYCT_FP_D8-Weekday-SDon-118400_B52_134'},
#         'JourneyPatternRef': 'MTA_B520052',
#         'LineRef': 'MTA NYCT_B52',
#         'Monitored': True,
#         'MonitoredCall': {'ExpectedArrivalTime': '2018-09-24T19:48:00.441-04:00',
#          'ExpectedDepartureTime': '2018-09-24T19:48:00.441-04:00',
#          'Extensions': {'Distances': {'CallDistanceAlongRoute': 610.65,
#            'DistanceFromCall': 59.8,
#            'PresentableDistance': 'approaching',
#            'StopsFromCall': 0}},
#          'StopPointName': 'ADAMS ST/BKLYN SUPREME CRT',
#          'StopPointRef': 'MTA_307460',
#          'VisitNumber': 1},
#         'OnwardCalls': {'OnwardCall': [{'ExpectedArrivalTime': '2018-09-24T19:48:00.441-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 610.65,
#              'DistanceFromCall': 59.8,
#              'PresentableDistance': 'approaching',
#              'StopsFromCall': 0}},
#            'StopPointName': 'ADAMS ST/BKLYN SUPREME CRT',
#            'StopPointRef': 'MTA_307460'},
#           {'ExpectedArrivalTime': '2018-09-24T19:49:28.041-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 810.21,
#              'DistanceFromCall': 259.35,
#              'PresentableDistance': '1 stop away',
#              'StopsFromCall': 1}},
#            'StopPointName': 'FULTON ST/SMITH ST',
#            'StopPointRef': 'MTA_302945'},
#           {'ExpectedArrivalTime': '2018-09-24T19:50:57.641-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 999.31,
#              'DistanceFromCall': 448.46,
#              'PresentableDistance': '2 stops away',
#              'StopsFromCall': 2}},
#            'StopPointName': 'FULTON ST/HOYT ST',
#            'StopPointRef': 'MTA_307491'},
#           {'ExpectedArrivalTime': '2018-09-24T19:52:37.241-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 1233.08,
#              'DistanceFromCall': 682.23,
#              'PresentableDistance': '3 stops away',
#              'StopsFromCall': 3}},
#            'StopPointName': 'FULTON ST/BOND ST',
#            'StopPointRef': 'MTA_302947'},
#           {'ExpectedArrivalTime': '2018-09-24T19:54:07.241-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 1406.74,
#              'DistanceFromCall': 855.89,
#              'PresentableDistance': '0.5 miles away',
#              'StopsFromCall': 4}},
#            'StopPointName': 'FULTON ST/FLATBUSH AV EXT',
#            'StopPointRef': 'MTA_302948'},
#           {'ExpectedArrivalTime': '2018-09-24T19:56:08.618-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 1696.87,
#              'DistanceFromCall': 1146.02,
#              'PresentableDistance': '0.7 miles away',
#              'StopsFromCall': 5}},
#            'StopPointName': 'FULTON ST/ASHLAND PL',
#            'StopPointRef': 'MTA_303017'},
#           {'ExpectedArrivalTime': '2018-09-24T19:56:51.260-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 1844.07,
#              'DistanceFromCall': 1293.22,
#              'PresentableDistance': '0.8 miles away',
#              'StopsFromCall': 6}},
#            'StopPointName': 'FULTON ST/LAFAYETTE AV',
#            'StopPointRef': 'MTA_302368'},
#           {'ExpectedArrivalTime': '2018-09-24T19:58:42.860-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 2098.42,
#              'DistanceFromCall': 1547.56,
#              'PresentableDistance': '1.0 miles away',
#              'StopsFromCall': 7}},
#            'StopPointName': 'FULTON ST/S PORTLAND AV',
#            'StopPointRef': 'MTA_302369'},
#           {'ExpectedArrivalTime': '2018-09-24T19:59:42.420-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 2232.18,
#              'DistanceFromCall': 1681.33,
#              'PresentableDistance': '1.0 miles away',
#              'StopsFromCall': 8}},
#            'StopPointName': 'GREENE AV/FULTON ST',
#            'StopPointRef': 'MTA_307547'},
#           {'ExpectedArrivalTime': '2018-09-24T20:00:59.799-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 2445.5,
#              'DistanceFromCall': 1894.65,
#              'PresentableDistance': '1.2 miles away',
#              'StopsFromCall': 9}},
#            'StopPointName': 'GREENE AV/ADELPHI ST',
#            'StopPointRef': 'MTA_307548'},
#           {'ExpectedArrivalTime': '2018-09-24T20:01:56.963-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 2617.34,
#              'DistanceFromCall': 2066.48,
#              'PresentableDistance': '1.3 miles away',
#              'StopsFromCall': 10}},
#            'StopPointName': 'GREENE AV/VANDERBILT AV',
#            'StopPointRef': 'MTA_307549'},
#           {'ExpectedArrivalTime': '2018-09-24T20:03:29.066-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 2867.09,
#              'DistanceFromCall': 2316.24,
#              'PresentableDistance': '1.4 miles away',
#              'StopsFromCall': 11}},
#            'StopPointName': 'GREENE AV/WASHINGTON AV',
#            'StopPointRef': 'MTA_307550'},
#           {'ExpectedArrivalTime': '2018-09-24T20:04:50.266-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 3125.5,
#              'DistanceFromCall': 2574.65,
#              'PresentableDistance': '1.6 miles away',
#              'StopsFromCall': 12}},
#            'StopPointName': 'GREENE AV/GRAND AV',
#            'StopPointRef': 'MTA_307551'},
#           {'ExpectedArrivalTime': '2018-09-24T20:05:57.572-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 3364.21,
#              'DistanceFromCall': 2813.36,
#              'PresentableDistance': '1.7 miles away',
#              'StopsFromCall': 13}},
#            'StopPointName': 'GREENE AV/CLASSON AV',
#            'StopPointRef': 'MTA_307552'},
#           {'ExpectedArrivalTime': '2018-09-24T20:06:59.772-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 3595.03,
#              'DistanceFromCall': 3044.17,
#              'PresentableDistance': '1.9 miles away',
#              'StopsFromCall': 14}},
#            'StopPointName': 'FRANKLIN AV/GREENE AV',
#            'StopPointRef': 'MTA_307553'},
#           {'ExpectedArrivalTime': '2018-09-24T20:08:07.172-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 3843.44,
#              'DistanceFromCall': 3292.58,
#              'PresentableDistance': '2.0 miles away',
#              'StopsFromCall': 15}},
#            'StopPointName': 'GATES AV/FRANKLIN AV',
#            'StopPointRef': 'MTA_307674'},
#           {'ExpectedArrivalTime': '2018-09-24T20:09:40.128-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4027.09,
#              'DistanceFromCall': 3476.23,
#              'PresentableDistance': '2.2 miles away',
#              'StopsFromCall': 16}},
#            'StopPointName': 'GATES AV/BEDFORD AV',
#            'StopPointRef': 'MTA_307675'},
#           {'ExpectedArrivalTime': '2018-09-24T20:10:39.304-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4291.16,
#              'DistanceFromCall': 3740.31,
#              'PresentableDistance': '2.3 miles away',
#              'StopsFromCall': 17}},
#            'StopPointName': 'GATES AV/NOSTRAND AV',
#            'StopPointRef': 'MTA_307676'},
#           {'ExpectedArrivalTime': '2018-09-24T20:12:27.704-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4616.54,
#              'DistanceFromCall': 4065.68,
#              'PresentableDistance': '2.5 miles away',
#              'StopsFromCall': 18}},
#            'StopPointName': 'GATES AV/MARCY AV',
#            'StopPointRef': 'MTA_307677'},
#           {'ExpectedArrivalTime': '2018-09-24T20:13:58.104-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4866.0,
#              'DistanceFromCall': 4315.14,
#              'PresentableDistance': '2.7 miles away',
#              'StopsFromCall': 19}},
#            'StopPointName': 'GATES AV/TOMPKINS AV',
#            'StopPointRef': 'MTA_307678'},
#           {'ExpectedArrivalTime': '2018-09-24T20:15:40.504-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5103.34,
#              'DistanceFromCall': 4552.48,
#              'PresentableDistance': '2.8 miles away',
#              'StopsFromCall': 20}},
#            'StopPointName': 'GATES AV/THROOP AV',
#            'StopPointRef': 'MTA_307679'},
#           {'ExpectedArrivalTime': '2018-09-24T20:16:50.170-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5342.21,
#              'DistanceFromCall': 4791.35,
#              'PresentableDistance': '3.0 miles away',
#              'StopsFromCall': 21}},
#            'StopPointName': 'GATES AV/MARCUS GARVEY BL',
#            'StopPointRef': 'MTA_307680'},
#           {'ExpectedArrivalTime': '2018-09-24T20:18:32.770-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5591.01,
#              'DistanceFromCall': 5040.15,
#              'PresentableDistance': '3.1 miles away',
#              'StopsFromCall': 22}},
#            'StopPointName': 'GATES AV/LEWIS AV',
#            'StopPointRef': 'MTA_307681'},
#           {'ExpectedArrivalTime': '2018-09-24T20:19:33.175-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5842.65,
#              'DistanceFromCall': 5291.79,
#              'PresentableDistance': '3.3 miles away',
#              'StopsFromCall': 23}},
#            'StopPointName': 'GATES AV/STUYVESANT AV',
#            'StopPointRef': 'MTA_307682'},
#           {'ExpectedArrivalTime': '2018-09-24T20:20:56.570-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6092.05,
#              'DistanceFromCall': 5541.19,
#              'PresentableDistance': '3.4 miles away',
#              'StopsFromCall': 24}},
#            'StopPointName': 'GATES AV/MALCOLM X BL',
#            'StopPointRef': 'MTA_307683'},
#           {'ExpectedArrivalTime': '2018-09-24T20:22:02.570-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6337.9,
#              'DistanceFromCall': 5787.04,
#              'PresentableDistance': '3.6 miles away',
#              'StopsFromCall': 25}},
#            'StopPointName': 'GATES AV/PATCHEN AV',
#            'StopPointRef': 'MTA_307684'},
#           {'ExpectedArrivalTime': '2018-09-24T20:23:02.770-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6572.3,
#              'DistanceFromCall': 6021.45,
#              'PresentableDistance': '3.7 miles away',
#              'StopsFromCall': 26}},
#            'StopPointName': 'GATES AV/RALPH AV',
#            'StopPointRef': 'MTA_307901'},
#           {'ExpectedArrivalTime': '2018-09-24T20:23:54.770-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6734.12,
#              'DistanceFromCall': 6183.27,
#              'PresentableDistance': '3.8 miles away',
#              'StopsFromCall': 27}},
#            'StopPointName': 'GATES AV/BROADWAY',
#            'StopPointRef': 'MTA_307686'},
#           {'ExpectedArrivalTime': '2018-09-24T20:26:09.569-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6977.66,
#              'DistanceFromCall': 6426.8,
#              'PresentableDistance': '4.0 miles away',
#              'StopsFromCall': 28}},
#            'StopPointName': 'GATES AV/BUSHWICK AV',
#            'StopPointRef': 'MTA_307687'},
#           {'ExpectedArrivalTime': '2018-09-24T20:27:15.528-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7146.91,
#              'DistanceFromCall': 6596.05,
#              'PresentableDistance': '4.1 miles away',
#              'StopsFromCall': 29}},
#            'StopPointName': 'GATES AV/EVERGREEN AV',
#            'StopPointRef': 'MTA_307688'},
#           {'ExpectedArrivalTime': '2018-09-24T20:28:22.624-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7388.47,
#              'DistanceFromCall': 6837.62,
#              'PresentableDistance': '4.2 miles away',
#              'StopsFromCall': 30}},
#            'StopPointName': 'GATES AV/CENTRAL AV',
#            'StopPointRef': 'MTA_307689'},
#           {'ExpectedArrivalTime': '2018-09-24T20:29:30.224-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7591.7,
#              'DistanceFromCall': 7040.84,
#              'PresentableDistance': '4.4 miles away',
#              'StopsFromCall': 31}},
#            'StopPointName': 'GATES AV/WILSON AV',
#            'StopPointRef': 'MTA_307690'},
#           {'ExpectedArrivalTime': '2018-09-24T20:30:31.663-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7797.59,
#              'DistanceFromCall': 7246.73,
#              'PresentableDistance': '4.5 miles away',
#              'StopsFromCall': 32}},
#            'StopPointName': 'GATES AV/KNICKERBOCKER AV',
#            'StopPointRef': 'MTA_307691'},
#           {'ExpectedArrivalTime': '2018-09-24T20:31:55.707-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 8098.58,
#              'DistanceFromCall': 7547.72,
#              'PresentableDistance': '4.7 miles away',
#              'StopsFromCall': 33}},
#            'StopPointName': 'PALMETTO ST/IRVING AV',
#            'StopPointRef': 'MTA_304415'},
#           {'ExpectedArrivalTime': '2018-09-24T20:32:28.541-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 8248.54,
#              'DistanceFromCall': 7697.68,
#              'PresentableDistance': '4.8 miles away',
#              'StopsFromCall': 34}},
#            'StopPointName': 'PALMETTO ST/WYCKOFF AV',
#            'StopPointRef': 'MTA_801117'}]},
#         'OperatorRef': 'MTA NYCT',
#         'OriginRef': 'MTA_307175',
#         'ProgressRate': 'normalProgress',
#         'PublishedLineName': 'B52',
#         'SituationRef': [],
#         'VehicleLocation': {'Latitude': 40.693103, 'Longitude': -73.989113},
#         'VehicleRef': 'MTA NYCT_7508'},
#        'RecordedAtTime': '2018-09-24T19:47:38.000-04:00'},
#       {'MonitoredVehicleJourney': {'Bearing': 6.589333,
#         'BlockRef': 'MTA NYCT_FP_D8-Weekday-SDon_E_FP_26040_B52-118',
#         'DestinationName': 'RIDGEWOOD TERM via GATES',
#         'DestinationRef': 'MTA_801117',
#         'DirectionRef': '0',
#         'FramedVehicleJourneyRef': {'DataFrameRef': '2018-09-24',
#          'DatedVehicleJourneyRef': 'MTA NYCT_FP_D8-Weekday-SDon-114400_B52_120'},
#         'JourneyPatternRef': 'MTA_B520052',
#         'LineRef': 'MTA NYCT_B52',
#         'Monitored': True,
#         'MonitoredCall': {'ExpectedArrivalTime': '2018-09-24T19:48:16.250-04:00',
#          'ExpectedDepartureTime': '2018-09-24T19:48:16.250-04:00',
#          'Extensions': {'Distances': {'CallDistanceAlongRoute': 6734.12,
#            'DistanceFromCall': 91.02,
#            'PresentableDistance': 'approaching',
#            'StopsFromCall': 0}},
#          'StopPointName': 'GATES AV/BROADWAY',
#          'StopPointRef': 'MTA_307686',
#          'VisitNumber': 1},
#         'OnwardCalls': {'OnwardCall': [{'ExpectedArrivalTime': '2018-09-24T19:48:16.250-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6734.12,
#              'DistanceFromCall': 91.02,
#              'PresentableDistance': 'approaching',
#              'StopsFromCall': 0}},
#            'StopPointName': 'GATES AV/BROADWAY',
#            'StopPointRef': 'MTA_307686'},
#           {'ExpectedArrivalTime': '2018-09-24T19:50:31.049-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6977.66,
#              'DistanceFromCall': 334.56,
#              'PresentableDistance': '1 stop away',
#              'StopsFromCall': 1}},
#            'StopPointName': 'GATES AV/BUSHWICK AV',
#            'StopPointRef': 'MTA_307687'},
#           {'ExpectedArrivalTime': '2018-09-24T19:51:37.008-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7146.91,
#              'DistanceFromCall': 503.81,
#              'PresentableDistance': '2 stops away',
#              'StopsFromCall': 2}},
#            'StopPointName': 'GATES AV/EVERGREEN AV',
#            'StopPointRef': 'MTA_307688'},
#           {'ExpectedArrivalTime': '2018-09-24T19:52:44.104-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7388.47,
#              'DistanceFromCall': 745.37,
#              'PresentableDistance': '3 stops away',
#              'StopsFromCall': 3}},
#            'StopPointName': 'GATES AV/CENTRAL AV',
#            'StopPointRef': 'MTA_307689'},
#           {'ExpectedArrivalTime': '2018-09-24T19:53:51.704-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7591.7,
#              'DistanceFromCall': 948.6,
#              'PresentableDistance': '0.6 miles away',
#              'StopsFromCall': 4}},
#            'StopPointName': 'GATES AV/WILSON AV',
#            'StopPointRef': 'MTA_307690'},
#           {'ExpectedArrivalTime': '2018-09-24T19:54:53.143-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7797.59,
#              'DistanceFromCall': 1154.49,
#              'PresentableDistance': '0.7 miles away',
#              'StopsFromCall': 5}},
#            'StopPointName': 'GATES AV/KNICKERBOCKER AV',
#            'StopPointRef': 'MTA_307691'},
#           {'ExpectedArrivalTime': '2018-09-24T19:56:17.187-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 8098.58,
#              'DistanceFromCall': 1455.48,
#              'PresentableDistance': '0.9 miles away',
#              'StopsFromCall': 6}},
#            'StopPointName': 'PALMETTO ST/IRVING AV',
#            'StopPointRef': 'MTA_304415'},
#           {'ExpectedArrivalTime': '2018-09-24T19:56:50.021-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 8248.54,
#              'DistanceFromCall': 1605.44,
#              'PresentableDistance': '1.0 miles away',
#              'StopsFromCall': 7}},
#            'StopPointName': 'PALMETTO ST/WYCKOFF AV',
#            'StopPointRef': 'MTA_801117'}]},
#         'OperatorRef': 'MTA NYCT',
#         'OriginRef': 'MTA_307175',
#         'ProgressRate': 'normalProgress',
#         'PublishedLineName': 'B52',
#         'SituationRef': [],
#         'VehicleLocation': {'Latitude': 40.689353, 'Longitude': -73.92329},
#         'VehicleRef': 'MTA NYCT_6591'},
#        'RecordedAtTime': '2018-09-24T19:47:47.000-04:00'},
#       {'MonitoredVehicleJourney': {'Bearing': 187.0017,
#         'BlockRef': 'MTA NYCT_FP_D8-Weekday-SDon_E_FP_45180_B52-119',
#         'DestinationName': 'DNTWN BKLYN TILLARY ST via GATES',
#         'DestinationRef': 'MTA_901463',
#         'DirectionRef': '1',
#         'FramedVehicleJourneyRef': {'DataFrameRef': '2018-09-24',
#          'DatedVehicleJourneyRef': 'MTA NYCT_FP_D8-Weekday-SDon-115200_B52_127'},
#         'JourneyPatternRef': 'MTA_B520053',
#         'LineRef': 'MTA NYCT_B52',
#         'Monitored': True,
#         'MonitoredCall': {'ExpectedArrivalTime': '2018-09-24T19:47:56.162-04:00',
#          'ExpectedDepartureTime': '2018-09-24T19:47:56.162-04:00',
#          'Extensions': {'Distances': {'CallDistanceAlongRoute': 2431.8,
#            'DistanceFromCall': 91.8,
#            'PresentableDistance': 'approaching',
#            'StopsFromCall': 0}},
#          'StopPointName': 'GATES AV/MALCOLM X BL',
#          'StopPointRef': 'MTA_304205',
#          'VisitNumber': 1},
#         'OnwardCalls': {'OnwardCall': [{'ExpectedArrivalTime': '2018-09-24T19:47:55.162-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 2431.8,
#              'DistanceFromCall': 91.8,
#              'PresentableDistance': 'approaching',
#              'StopsFromCall': 0}},
#            'StopPointName': 'GATES AV/MALCOLM X BL',
#            'StopPointRef': 'MTA_304205'},
#           {'ExpectedArrivalTime': '2018-09-24T19:48:32.849-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 2680.54,
#              'DistanceFromCall': 340.55,
#              'PresentableDistance': '1 stop away',
#              'StopsFromCall': 1}},
#            'StopPointName': 'GATES AV/STUYVESANT AV',
#            'StopPointRef': 'MTA_304206'},
#           {'ExpectedArrivalTime': '2018-09-24T19:49:28.202-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 2883.4,
#              'DistanceFromCall': 543.41,
#              'PresentableDistance': '2 stops away',
#              'StopsFromCall': 2}},
#            'StopPointName': 'GATES AV/LEWIS AV',
#            'StopPointRef': 'MTA_304207'},
#           {'ExpectedArrivalTime': '2018-09-24T19:51:17.796-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 3179.52,
#              'DistanceFromCall': 839.53,
#              'PresentableDistance': '0.5 miles away',
#              'StopsFromCall': 3}},
#            'StopPointName': 'GATES AV/MARCUS GARVEY BL',
#            'StopPointRef': 'MTA_306530'},
#           {'ExpectedArrivalTime': '2018-09-24T19:52:25.604-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 3373.21,
#              'DistanceFromCall': 1033.22,
#              'PresentableDistance': '0.6 miles away',
#              'StopsFromCall': 4}},
#            'StopPointName': 'GATES AV/THROOP AV',
#            'StopPointRef': 'MTA_304209'},
#           {'ExpectedArrivalTime': '2018-09-24T19:54:00.604-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 3659.6,
#              'DistanceFromCall': 1319.61,
#              'PresentableDistance': '0.8 miles away',
#              'StopsFromCall': 5}},
#            'StopPointName': 'GATES AV/TOMPKINS AV',
#            'StopPointRef': 'MTA_304210'},
#           {'ExpectedArrivalTime': '2018-09-24T19:55:08.723-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 3903.29,
#              'DistanceFromCall': 1563.3,
#              'PresentableDistance': '1.0 miles away',
#              'StopsFromCall': 6}},
#            'StopPointName': 'GATES AV/MARCY AV',
#            'StopPointRef': 'MTA_304211'},
#           {'ExpectedArrivalTime': '2018-09-24T19:56:46.923-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4183.96,
#              'DistanceFromCall': 1843.97,
#              'PresentableDistance': '1.1 miles away',
#              'StopsFromCall': 7}},
#            'StopPointName': 'GATES AV/NOSTRAND AV',
#            'StopPointRef': 'MTA_304212'},
#           {'ExpectedArrivalTime': '2018-09-24T19:58:32.300-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4497.03,
#              'DistanceFromCall': 2157.04,
#              'PresentableDistance': '1.3 miles away',
#              'StopsFromCall': 8}},
#            'StopPointName': 'GATES AV/BEDFORD AV',
#            'StopPointRef': 'MTA_304213'},
#           {'ExpectedArrivalTime': '2018-09-24T19:59:38.042-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4676.87,
#              'DistanceFromCall': 2336.88,
#              'PresentableDistance': '1.5 miles away',
#              'StopsFromCall': 9}},
#            'StopPointName': 'GATES AV/FRANKLIN AV',
#            'StopPointRef': 'MTA_304214'},
#           {'ExpectedArrivalTime': '2018-09-24T20:00:28.612-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4864.43,
#              'DistanceFromCall': 2524.44,
#              'PresentableDistance': '1.6 miles away',
#              'StopsFromCall': 10}},
#            'StopPointName': 'GATES AV/CLASSON AV',
#            'StopPointRef': 'MTA_307948'},
#           {'ExpectedArrivalTime': '2018-09-24T20:02:04.612-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5156.07,
#              'DistanceFromCall': 2816.08,
#              'PresentableDistance': '1.7 miles away',
#              'StopsFromCall': 11}},
#            'StopPointName': 'GREENE AV/CLASSON AV',
#            'StopPointRef': 'MTA_307572'},
#           {'ExpectedArrivalTime': '2018-09-24T20:03:03.883-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5397.42,
#              'DistanceFromCall': 3057.43,
#              'PresentableDistance': '1.9 miles away',
#              'StopsFromCall': 12}},
#            'StopPointName': 'GREENE AV/GRAND AV',
#            'StopPointRef': 'MTA_307573'},
#           {'ExpectedArrivalTime': '2018-09-24T20:04:15.499-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5655.77,
#              'DistanceFromCall': 3315.78,
#              'PresentableDistance': '2.1 miles away',
#              'StopsFromCall': 13}},
#            'StopPointName': 'GREENE AV/WASHINGTON AV',
#            'StopPointRef': 'MTA_307596'},
#           {'ExpectedArrivalTime': '2018-09-24T20:05:33.909-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5907.49,
#              'DistanceFromCall': 3567.5,
#              'PresentableDistance': '2.2 miles away',
#              'StopsFromCall': 14}},
#            'StopPointName': 'GREENE AV/VANDERBILT AV',
#            'StopPointRef': 'MTA_307575'},
#           {'ExpectedArrivalTime': '2018-09-24T20:06:26.557-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6074.28,
#              'DistanceFromCall': 3734.29,
#              'PresentableDistance': '2.3 miles away',
#              'StopsFromCall': 15}},
#            'StopPointName': 'GREENE AV/ADELPHI ST',
#            'StopPointRef': 'MTA_307576'},
#           {'ExpectedArrivalTime': '2018-09-24T20:07:18.701-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6238.78,
#              'DistanceFromCall': 3898.79,
#              'PresentableDistance': '2.4 miles away',
#              'StopsFromCall': 16}},
#            'StopPointName': 'GREENE AV/CUMBERLAND ST',
#            'StopPointRef': 'MTA_307577'},
#           {'ExpectedArrivalTime': '2018-09-24T20:09:01.507-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6487.03,
#              'DistanceFromCall': 4147.04,
#              'PresentableDistance': '2.6 miles away',
#              'StopsFromCall': 17}},
#            'StopPointName': 'FULTON ST/S ELLIOTT PL',
#            'StopPointRef': 'MTA_302427'},
#           {'ExpectedArrivalTime': '2018-09-24T20:10:05.503-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6642.98,
#              'DistanceFromCall': 4302.99,
#              'PresentableDistance': '2.7 miles away',
#              'StopsFromCall': 18}},
#            'StopPointName': 'FULTON ST/FT GREENE PL',
#            'StopPointRef': 'MTA_302428'},
#           {'ExpectedArrivalTime': '2018-09-24T20:11:59.703-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6942.37,
#              'DistanceFromCall': 4602.38,
#              'PresentableDistance': '2.9 miles away',
#              'StopsFromCall': 19}},
#            'StopPointName': 'FULTON ST/HUDSON AV',
#            'StopPointRef': 'MTA_302430'},
#           {'ExpectedArrivalTime': '2018-09-24T20:13:50.972-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7193.37,
#              'DistanceFromCall': 4853.38,
#              'PresentableDistance': '3.0 miles away',
#              'StopsFromCall': 20}},
#            'StopPointName': 'FULTON ST/BOND ST',
#            'StopPointRef': 'MTA_302431'},
#           {'ExpectedArrivalTime': '2018-09-24T20:14:59.987-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7397.6,
#              'DistanceFromCall': 5057.61,
#              'PresentableDistance': '3.1 miles away',
#              'StopsFromCall': 21}},
#            'StopPointName': 'FULTON ST/DUFFIELD ST',
#            'StopPointRef': 'MTA_307492'},
#           {'ExpectedArrivalTime': '2018-09-24T20:16:09.387-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7605.4,
#              'DistanceFromCall': 5265.41,
#              'PresentableDistance': '3.3 miles away',
#              'StopsFromCall': 22}},
#            'StopPointName': 'FULTON ST/JAY ST',
#            'StopPointRef': 'MTA_302433'},
#           {'ExpectedArrivalTime': '2018-09-24T20:18:19.987-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7931.22,
#              'DistanceFromCall': 5591.23,
#              'PresentableDistance': '3.5 miles away',
#              'StopsFromCall': 23}},
#            'StopPointName': 'JORALEMON ST/COURT ST',
#            'StopPointRef': 'MTA_302434'},
#           {'Extensions': {'Distances': {'CallDistanceAlongRoute': 8065.26,
#              'DistanceFromCall': 5725.27,
#              'PresentableDistance': '3.6 miles away',
#              'StopsFromCall': 24}},
#            'StopPointName': 'CADMAN PLZ W/MONTAGUE ST',
#            'StopPointRef': 'MTA_306533'},
#           {'ExpectedArrivalTime': '2018-09-24T20:19:17.831-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 8096.35,
#              'DistanceFromCall': 5756.36,
#              'PresentableDistance': '3.6 miles away',
#              'StopsFromCall': 25}},
#            'StopPointName': 'CADMAN PZ W/TILLARY ST',
# ...
#              'StopsFromCall': 1}},
#            'StopPointName': 'FULTON ST/HOYT ST',
#            'StopPointRef': 'MTA_307491'},
#           {'ExpectedArrivalTime': '2018-09-24T19:51:51.287-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 1233.08,
#              'DistanceFromCall': 587.09,
#              'PresentableDistance': '2 stops away',
#              'StopsFromCall': 2}},
#            'StopPointName': 'FULTON ST/BOND ST',
#            'StopPointRef': 'MTA_302947'},
#           {'ExpectedArrivalTime': '2018-09-24T19:53:21.287-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 1406.74,
#              'DistanceFromCall': 760.75,
#              'PresentableDistance': '3 stops away',
#              'StopsFromCall': 3}},
#            'StopPointName': 'FULTON ST/FLATBUSH AV EXT',
#            'StopPointRef': 'MTA_302948'},
#           {'ExpectedArrivalTime': '2018-09-24T19:55:22.664-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 1696.87,
#              'DistanceFromCall': 1050.88,
#              'PresentableDistance': '0.7 miles away',
#              'StopsFromCall': 4}},
#            'StopPointName': 'FULTON ST/ASHLAND PL',
#            'StopPointRef': 'MTA_303017'},
#           {'ExpectedArrivalTime': '2018-09-24T19:56:05.306-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 1844.07,
#              'DistanceFromCall': 1198.08,
#              'PresentableDistance': '0.7 miles away',
#              'StopsFromCall': 5}},
#            'StopPointName': 'FULTON ST/LAFAYETTE AV',
#            'StopPointRef': 'MTA_302368'},
#           {'ExpectedArrivalTime': '2018-09-24T19:57:56.906-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 2098.42,
#              'DistanceFromCall': 1452.43,
#              'PresentableDistance': '0.9 miles away',
#              'StopsFromCall': 6}},
#            'StopPointName': 'FULTON ST/S PORTLAND AV',
#            'StopPointRef': 'MTA_302369'},
#           {'ExpectedArrivalTime': '2018-09-24T19:58:56.466-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 2232.18,
#              'DistanceFromCall': 1586.19,
#              'PresentableDistance': '1.0 miles away',
#              'StopsFromCall': 7}},
#            'StopPointName': 'GREENE AV/FULTON ST',
#            'StopPointRef': 'MTA_307547'},
#           {'ExpectedArrivalTime': '2018-09-24T20:00:13.845-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 2445.5,
#              'DistanceFromCall': 1799.51,
#              'PresentableDistance': '1.1 miles away',
#              'StopsFromCall': 8}},
#            'StopPointName': 'GREENE AV/ADELPHI ST',
#            'StopPointRef': 'MTA_307548'},
#           {'ExpectedArrivalTime': '2018-09-24T20:01:11.009-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 2617.34,
#              'DistanceFromCall': 1971.35,
#              'PresentableDistance': '1.2 miles away',
#              'StopsFromCall': 9}},
#            'StopPointName': 'GREENE AV/VANDERBILT AV',
#            'StopPointRef': 'MTA_307549'},
#           {'ExpectedArrivalTime': '2018-09-24T20:02:43.112-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 2867.09,
#              'DistanceFromCall': 2221.1,
#              'PresentableDistance': '1.4 miles away',
#              'StopsFromCall': 10}},
#            'StopPointName': 'GREENE AV/WASHINGTON AV',
#            'StopPointRef': 'MTA_307550'},
#           {'ExpectedArrivalTime': '2018-09-24T20:04:04.312-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 3125.5,
#              'DistanceFromCall': 2479.51,
#              'PresentableDistance': '1.5 miles away',
#              'StopsFromCall': 11}},
#            'StopPointName': 'GREENE AV/GRAND AV',
#            'StopPointRef': 'MTA_307551'},
#           {'ExpectedArrivalTime': '2018-09-24T20:05:11.618-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 3364.21,
#              'DistanceFromCall': 2718.22,
#              'PresentableDistance': '1.7 miles away',
#              'StopsFromCall': 12}},
#            'StopPointName': 'GREENE AV/CLASSON AV',
#            'StopPointRef': 'MTA_307552'},
#           {'ExpectedArrivalTime': '2018-09-24T20:06:13.818-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 3595.03,
#              'DistanceFromCall': 2949.04,
#              'PresentableDistance': '1.8 miles away',
#              'StopsFromCall': 13}},
#            'StopPointName': 'FRANKLIN AV/GREENE AV',
#            'StopPointRef': 'MTA_307553'},
#           {'ExpectedArrivalTime': '2018-09-24T20:07:21.218-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 3843.44,
#              'DistanceFromCall': 3197.45,
#              'PresentableDistance': '2.0 miles away',
#              'StopsFromCall': 14}},
#            'StopPointName': 'GATES AV/FRANKLIN AV',
#            'StopPointRef': 'MTA_307674'},
#           {'ExpectedArrivalTime': '2018-09-24T20:08:54.174-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4027.09,
#              'DistanceFromCall': 3381.1,
#              'PresentableDistance': '2.1 miles away',
#              'StopsFromCall': 15}},
#            'StopPointName': 'GATES AV/BEDFORD AV',
#            'StopPointRef': 'MTA_307675'},
#           {'ExpectedArrivalTime': '2018-09-24T20:09:53.350-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4291.16,
#              'DistanceFromCall': 3645.17,
#              'PresentableDistance': '2.3 miles away',
#              'StopsFromCall': 16}},
#            'StopPointName': 'GATES AV/NOSTRAND AV',
#            'StopPointRef': 'MTA_307676'},
#           {'ExpectedArrivalTime': '2018-09-24T20:11:41.750-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4616.54,
#              'DistanceFromCall': 3970.54,
#              'PresentableDistance': '2.5 miles away',
#              'StopsFromCall': 17}},
#            'StopPointName': 'GATES AV/MARCY AV',
#            'StopPointRef': 'MTA_307677'},
#           {'ExpectedArrivalTime': '2018-09-24T20:13:12.150-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 4866.0,
#              'DistanceFromCall': 4220.01,
#              'PresentableDistance': '2.6 miles away',
#              'StopsFromCall': 18}},
#            'StopPointName': 'GATES AV/TOMPKINS AV',
#            'StopPointRef': 'MTA_307678'},
#           {'ExpectedArrivalTime': '2018-09-24T20:14:54.550-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5103.34,
#              'DistanceFromCall': 4457.35,
#              'PresentableDistance': '2.8 miles away',
#              'StopsFromCall': 19}},
#            'StopPointName': 'GATES AV/THROOP AV',
#            'StopPointRef': 'MTA_307679'},
#           {'ExpectedArrivalTime': '2018-09-24T20:16:04.216-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5342.21,
#              'DistanceFromCall': 4696.22,
#              'PresentableDistance': '2.9 miles away',
#              'StopsFromCall': 20}},
#            'StopPointName': 'GATES AV/MARCUS GARVEY BL',
#            'StopPointRef': 'MTA_307680'},
#           {'ExpectedArrivalTime': '2018-09-24T20:17:46.816-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5591.01,
#              'DistanceFromCall': 4945.01,
#              'PresentableDistance': '3.1 miles away',
#              'StopsFromCall': 21}},
#            'StopPointName': 'GATES AV/LEWIS AV',
#            'StopPointRef': 'MTA_307681'},
#           {'ExpectedArrivalTime': '2018-09-24T20:18:47.221-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 5842.65,
#              'DistanceFromCall': 5196.66,
#              'PresentableDistance': '3.2 miles away',
#              'StopsFromCall': 22}},
#            'StopPointName': 'GATES AV/STUYVESANT AV',
#            'StopPointRef': 'MTA_307682'},
#           {'ExpectedArrivalTime': '2018-09-24T20:20:10.616-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6092.05,
#              'DistanceFromCall': 5446.06,
#              'PresentableDistance': '3.4 miles away',
#              'StopsFromCall': 23}},
#            'StopPointName': 'GATES AV/MALCOLM X BL',
#            'StopPointRef': 'MTA_307683'},
#           {'ExpectedArrivalTime': '2018-09-24T20:21:16.616-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6337.9,
#              'DistanceFromCall': 5691.9,
#              'PresentableDistance': '3.5 miles away',
#              'StopsFromCall': 24}},
#            'StopPointName': 'GATES AV/PATCHEN AV',
#            'StopPointRef': 'MTA_307684'},
#           {'ExpectedArrivalTime': '2018-09-24T20:22:16.816-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6572.3,
#              'DistanceFromCall': 5926.31,
#              'PresentableDistance': '3.7 miles away',
#              'StopsFromCall': 25}},
#            'StopPointName': 'GATES AV/RALPH AV',
#            'StopPointRef': 'MTA_307901'},
#           {'ExpectedArrivalTime': '2018-09-24T20:23:08.816-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6734.12,
#              'DistanceFromCall': 6088.13,
#              'PresentableDistance': '3.8 miles away',
#              'StopsFromCall': 26}},
#            'StopPointName': 'GATES AV/BROADWAY',
#            'StopPointRef': 'MTA_307686'},
#           {'ExpectedArrivalTime': '2018-09-24T20:25:23.615-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 6977.66,
#              'DistanceFromCall': 6331.66,
#              'PresentableDistance': '3.9 miles away',
#              'StopsFromCall': 27}},
#            'StopPointName': 'GATES AV/BUSHWICK AV',
#            'StopPointRef': 'MTA_307687'},
#           {'ExpectedArrivalTime': '2018-09-24T20:26:29.574-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7146.91,
#              'DistanceFromCall': 6500.91,
#              'PresentableDistance': '4.0 miles away',
#              'StopsFromCall': 28}},
#            'StopPointName': 'GATES AV/EVERGREEN AV',
#            'StopPointRef': 'MTA_307688'},
#           {'ExpectedArrivalTime': '2018-09-24T20:27:36.670-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7388.47,
#              'DistanceFromCall': 6742.48,
#              'PresentableDistance': '4.2 miles away',
#              'StopsFromCall': 29}},
#            'StopPointName': 'GATES AV/CENTRAL AV',
#            'StopPointRef': 'MTA_307689'},
#           {'ExpectedArrivalTime': '2018-09-24T20:28:44.270-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7591.7,
#              'DistanceFromCall': 6945.71,
#              'PresentableDistance': '4.3 miles away',
#              'StopsFromCall': 30}},
#            'StopPointName': 'GATES AV/WILSON AV',
#            'StopPointRef': 'MTA_307690'},
#           {'ExpectedArrivalTime': '2018-09-24T20:29:45.709-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7797.59,
#              'DistanceFromCall': 7151.6,
#              'PresentableDistance': '4.4 miles away',
#              'StopsFromCall': 31}},
#            'StopPointName': 'GATES AV/KNICKERBOCKER AV',
#            'StopPointRef': 'MTA_307691'},
#           {'ExpectedArrivalTime': '2018-09-24T20:31:09.753-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 8098.58,
#              'DistanceFromCall': 7452.59,
#              'PresentableDistance': '4.6 miles away',
#              'StopsFromCall': 32}},
#            'StopPointName': 'PALMETTO ST/IRVING AV',
#            'StopPointRef': 'MTA_304415'},
#           {'ExpectedArrivalTime': '2018-09-24T20:31:42.587-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 8248.54,
#              'DistanceFromCall': 7602.55,
#              'PresentableDistance': '4.7 miles away',
#              'StopsFromCall': 33}},
#            'StopPointName': 'PALMETTO ST/WYCKOFF AV',
#            'StopPointRef': 'MTA_801117'}]},
#         'OperatorRef': 'MTA NYCT',
#         'OriginRef': 'MTA_307175',
#         'ProgressRate': 'normalProgress',
#         'PublishedLineName': 'B52',
#         'SituationRef': [],
#         'VehicleLocation': {'Latitude': 40.692264, 'Longitude': -73.989032},
#         'VehicleRef': 'MTA NYCT_6515'},
#        'RecordedAtTime': '2018-09-24T19:47:30.000-04:00'},
#       {'MonitoredVehicleJourney': {'Bearing': 100.06069,
#         'BlockRef': 'MTA NYCT_FP_D8-Weekday-SDon_E_FP_22080_B52-109',
#         'DestinationName': 'DNTWN BKLYN TILLARY ST via GATES',
#         'DestinationRef': 'MTA_901463',
#         'DirectionRef': '1',
#         'FramedVehicleJourneyRef': {'DataFrameRef': '2018-09-24',
#          'DatedVehicleJourneyRef': 'MTA NYCT_FP_D8-Weekday-SDon-113600_B52_135'},
#         'JourneyPatternRef': 'MTA_B520053',
#         'LineRef': 'MTA NYCT_B52',
#         'Monitored': True,
#         'MonitoredCall': {'Extensions': {'Distances': {'CallDistanceAlongRoute': 0.09,
#            'DistanceFromCall': 208.71,
#            'PresentableDistance': '< 1 stop away',
#            'StopsFromCall': 0}},
#          'StopPointName': 'CADMAN PZ W/TILLARY ST',
#          'StopPointRef': 'MTA_307175',
#          'VisitNumber': 1},
#         'OnwardCalls': {},
#         'OperatorRef': 'MTA NYCT',
#         'OriginAimedDepartureTime': '2018-09-24T20:00:00.000-04:00',
#         'OriginRef': 'MTA_504965',
#         'ProgressRate': 'noProgress',
#         'ProgressStatus': 'layover',
#         'PublishedLineName': 'B52',
#         'SituationRef': [],
#         'VehicleLocation': {'Latitude': 40.693866, 'Longitude': -73.990441},
#         'VehicleRef': 'MTA NYCT_6508'},
#        'RecordedAtTime': '2018-09-24T19:47:37.000-04:00'},
#       {'MonitoredVehicleJourney': {'Bearing': 158.87527,
#         'BlockRef': 'MTA NYCT_FP_D8-Weekday-SDon_E_FP_59460_B52-125',
#         'DestinationName': 'DNTWN BKLYN TILLARY ST via GATES',
#         'DestinationRef': 'MTA_901463',
#         'DirectionRef': '1',
#         'FramedVehicleJourneyRef': {'DataFrameRef': '2018-09-24',
#          'DatedVehicleJourneyRef': 'MTA NYCT_FP_D8-Weekday-SDon-114400_B52_125'},
#         'JourneyPatternRef': 'MTA_B520053',
#         'LineRef': 'MTA NYCT_B52',
#         'Monitored': True,
#         'MonitoredCall': {'ExpectedArrivalTime': '2018-09-24T19:49:39.886-04:00',
#          'ExpectedDepartureTime': '2018-09-24T19:49:39.886-04:00',
#          'Extensions': {'Distances': {'CallDistanceAlongRoute': 7931.22,
#            'DistanceFromCall': 276.63,
#            'PresentableDistance': '< 1 stop away',
#            'StopsFromCall': 0}},
#          'StopPointName': 'JORALEMON ST/COURT ST',
#          'StopPointRef': 'MTA_302434',
#          'VisitNumber': 1},
#         'OnwardCalls': {'OnwardCall': [{'ExpectedArrivalTime': '2018-09-24T19:49:39.886-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 7931.22,
#              'DistanceFromCall': 276.63,
#              'PresentableDistance': '< 1 stop away',
#              'StopsFromCall': 0}},
#            'StopPointName': 'JORALEMON ST/COURT ST',
#            'StopPointRef': 'MTA_302434'},
#           {'Extensions': {'Distances': {'CallDistanceAlongRoute': 8065.26,
#              'DistanceFromCall': 410.68,
#              'PresentableDistance': '1 stop away',
#              'StopsFromCall': 1}},
#            'StopPointName': 'CADMAN PLZ W/MONTAGUE ST',
#            'StopPointRef': 'MTA_306533'},
#           {'ExpectedArrivalTime': '2018-09-24T19:50:37.730-04:00',
#            'Extensions': {'Distances': {'CallDistanceAlongRoute': 8096.35,
#              'DistanceFromCall': 441.77,
#              'PresentableDistance': '2 stops away',
#              'StopsFromCall': 2}},
#            'StopPointName': 'CADMAN PZ W/TILLARY ST',
#            'StopPointRef': 'MTA_901463'}]},
#         'OperatorRef': 'MTA NYCT',
#         'OriginRef': 'MTA_504965',
#         'ProgressRate': 'normalProgress',
#         'PublishedLineName': 'B52',
#         'SituationRef': [],
#         'VehicleLocation': {'Latitude': 40.691567, 'Longitude': -73.987679},
#         'VehicleRef': 'MTA NYCT_7255'},
#        'RecordedAtTime': '2018-09-24T19:47:49.000-04:00'}]}]}}}

# %%
data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][0]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]['Extensions']['Distances']['PresentableDistance']
# Out:
# 'at stop'

# %%
data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][0]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]['StopPointName']
# Out:
# 'GATES AV/BEDFORD AV'

# %%
(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][bus]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]['Extensions']['Distances']['PresentableDistance'])

# %%
for bus in range(len(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'])):
    print("Bus " + str(bus)+" is at Latitude "+str(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][bus]['MonitoredVehicleJourney']['VehicleLocation']['Latitude'])+ " and Longitude "+str(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][bus]['MonitoredVehicleJourney']['VehicleLocation']['Longitude']))
    
    if bool(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][bus]['MonitoredVehicleJourney']['OnwardCalls']):
        print(str(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][bus]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]['Extensions']['Distances']['PresentableDistance']))
        print(str(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][0]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]['StopPointName']))
    else:
        print('N/A')
        print('N/A')
# Out:
# Bus 0 is at Latitude 40.68581 and Longitude -73.954035
# at stop
# GATES AV/BEDFORD AV
# Bus 1 is at Latitude 40.693866 and Longitude -73.990441
# N/A
# N/A
# Bus 2 is at Latitude 40.69618 and Longitude -73.990635
# approaching
# GATES AV/BEDFORD AV
# Bus 3 is at Latitude 40.6866 and Longitude -73.959547
# approaching
# GATES AV/BEDFORD AV
# Bus 4 is at Latitude 40.686374 and Longitude -73.959504
# approaching
# GATES AV/BEDFORD AV
# Bus 5 is at Latitude 40.688403 and Longitude -73.931358
# < 1 stop away
# GATES AV/BEDFORD AV
# Bus 6 is at Latitude 40.68948 and Longitude -73.922186
# < 1 stop away
# GATES AV/BEDFORD AV

# %%
Lat=str(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][bus]['MonitoredVehicleJourney']['VehicleLocation']['Latitude'])

# %%
print(Lat)
# Out:
# 40.68948

# %%
Long=str(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][bus]['MonitoredVehicleJourney']['VehicleLocation']['Longitude'])

# %%
print(Long)
# Out:
# -73.922186

# %%
StopName=str(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][0]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]['StopPointName'])

# %%
print(StopName)
# Out:
# GATES AV/BEDFORD AV

# %%
StopPoint=str(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][bus]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]['Extensions']['Distances']['PresentableDistance'])

# %%
print(StopPoint)
# Out:
# < 1 stop away

# %%
for bus in range(len(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'])):
    #print("Bus " + str(bus)+" is at Latitude "+str(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][bus]['MonitoredVehicleJourney']['VehicleLocation']['Latitude'])+ " and Longitude "+str(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][bus]['MonitoredVehicleJourney']['VehicleLocation']['Longitude']))
    Lat=str(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][bus]['MonitoredVehicleJourney']['VehicleLocation']['Latitude'])
    Long=str(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][bus]['MonitoredVehicleJourney']['VehicleLocation']['Longitude'])
        
    if bool(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][bus]['MonitoredVehicleJourney']['OnwardCalls']):
        StopPoint=str(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][bus]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]['Extensions']['Distances']['PresentableDistance'])
        StopName=str(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][0]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]['StopPointName'])
        print(Lat+","+Long+","+StopPoint+","+StopName)
        
    else:
        print(Lat+","+Long+","+'N/A,N/A')
# Out:
# 40.68581,-73.954035,at stop,GATES AV/BEDFORD AV
# 40.693866,-73.990441,N/A,N/A
# 40.69618,-73.990635,approaching,GATES AV/BEDFORD AV
# 40.6866,-73.959547,approaching,GATES AV/BEDFORD AV
# 40.686374,-73.959504,approaching,GATES AV/BEDFORD AV
# 40.688403,-73.931358,< 1 stop away,GATES AV/BEDFORD AV
# 40.68948,-73.922186,< 1 stop away,GATES AV/BEDFORD AV

# %%
for bus in range(len(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'])):
    #print("Bus " + str(bus)+" is at Latitude "+str(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][bus]['MonitoredVehicleJourney']['VehicleLocation']['Latitude'])+ " and Longitude "+str(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][bus]['MonitoredVehicleJourney']['VehicleLocation']['Longitude']))
    Lat=str(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][bus]['MonitoredVehicleJourney']['VehicleLocation']['Latitude'])
    Long=str(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][bus]['MonitoredVehicleJourney']['VehicleLocation']['Longitude'])
        
    if bool(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][bus]['MonitoredVehicleJourney']['OnwardCalls']):
        StopPoint=str(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][bus]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]['Extensions']['Distances']['PresentableDistance'])
        StopName=str(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][0]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]['StopPointName'])
        (Lat+","+Long+","+StopPoint+","+StopName)
        
    else:
        print(Lat+","+Long+","+'N/A,N/A')
